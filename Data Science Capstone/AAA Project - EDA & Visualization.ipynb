# %% [markdown]
# # AAA Project - EDA & Visualization
# ### Katharine Cross

# %%
# Initial Imports 

import pandas as pd
import seaborn as sns
import numpy as np
from numpy import median
import matplotlib.pyplot as plt

# %%
# Import Data

clean_df=pd.read_csv('AAA_Cleaned4.csv')

# %%
clean_df.head()
# Out:
#    individual_key  individual_key.1  individual_key.2        age children  \
# 0         15294.0           15294.0           15294.0  31.000000       No
# 1         16996.0           16996.0           16996.0  21.000000       No
# 2         18708.0           18708.0           18708.0  54.000000      Yes
# 3         19350.0           19350.0           19350.0  58.000000  Unknown
# 4         35518.0           35518.0           35518.0  58.478336      Yes
#
#                      dwelling_type          education estimated_income_code  \
# 0  Multi Family Dwelling/Apartment        High School       $15,000-$19,999
# 1                    Single Family            Unknown     $100,000-$149,999
# 2                    Single Family  Completed College     $150,000-$174,999
# 3                          Unknown            Unknown                   NaN
# 4  Multi Family Dwelling/Apartment        High School                   NaN
#
#   marital_status gender  ... upgrade_membership  \
# ...

# %%
clean_df.shape
# Out:
# (10481, 30)

# %%
clean_df.columns
# Out:
# Index(['individual_key', 'individual_key.1', 'individual_key.2', 'age',
#        'children', 'dwelling_type', 'education', 'estimated_income_code',
#        'marital_status', 'gender', 'state', 'race_cleaned', 'city_cleaned',
#        'offer_name', 'accepted', 'numofoffers', 'acceptedoffers',
#        'add_associate', 'auto-renew', 'offer_protectmyid',
#        'upgrade_membership', 'consumerview_profitability_score',
#        'count_clicks_or_opens', 'credit_ranges', 'donor_flag',
#        'drv_driving_school_flag', 'occupation_group', 'member_tenure_years',
#        'member_type', 'Average_Member_yrcost'],
#       dtype='object')

# %% [markdown]
# ## STEP #1: Column Count Plots

# %%
sns.countplot(x=clean_df["children"])
# Out:
# <AxesSubplot:xlabel='children', ylabel='count'>

# %%
sns.countplot(x=clean_df["dwelling_type"])
# Out:
# <AxesSubplot:xlabel='dwelling_type', ylabel='count'>

# %%
sns.countplot(x=clean_df["education"])
# Out:
# <AxesSubplot:xlabel='education', ylabel='count'>

# %%
sns.countplot(x="marital_status",data=clean_df)
# Out:
# <AxesSubplot:xlabel='marital_status', ylabel='count'>

# %%
sns.countplot(x="gender",data=clean_df)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.countplot(x="state",data=clean_df)
# Out:
# <AxesSubplot:xlabel='state', ylabel='count'>

# %%
sns.countplot(x="offer_name",data=clean_df)
# Out:
# <AxesSubplot:xlabel='offer_name', ylabel='count'>

# %%
sns.countplot(x="accepted",data=clean_df)
# Out:
# <AxesSubplot:xlabel='accepted', ylabel='count'>

# %%
sns.countplot(x="numofoffers",data=clean_df)
# Out:
# <AxesSubplot:xlabel='numofoffers', ylabel='count'>

# %%
sns.countplot(x="acceptedoffers",data=clean_df)
# Out:
# <AxesSubplot:xlabel='acceptedoffers', ylabel='count'>

# %%
sns.countplot(x="auto-renew",data=clean_df)
# Out:
# <AxesSubplot:xlabel='auto-renew', ylabel='count'>

# %%
sns.countplot(x="offer_protectmyid",data=clean_df)
# Out:
# <AxesSubplot:xlabel='offer_protectmyid', ylabel='count'>

# %%
sns.countplot(x="upgrade_membership",data=clean_df)
# Out:
# <AxesSubplot:xlabel='upgrade_membership', ylabel='count'>

# %%
sns.countplot(x="consumerview_profitability_score",data=clean_df)
# Out:
# <AxesSubplot:xlabel='consumerview_profitability_score', ylabel='count'>

# %%
sns.countplot(x="credit_ranges",data=clean_df)
# Out:
# <AxesSubplot:xlabel='credit_ranges', ylabel='count'>

# %%
sns.barplot(x="offer_name", y="accepted", data=clean_df)
# Out:
# <AxesSubplot:xlabel='offer_name', ylabel='accepted'>

# %%
sns.barplot(x="numofoffers", y="accepted", data=clean_df)
# Out:
# <AxesSubplot:xlabel='numofoffers', ylabel='accepted'>

# %%
sns.barplot(x="member_tenure_years", y="accepted", data=clean_df)
plt.xticks(rotation=90, ha="right") 
plt.figure(figsize=(90, 60)) 
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Assuming 'member_tenure_years' is a categorical variable
# Replace it with your actual variable name
sns.barplot(x="member_tenure_years", y="accepted", data=clean_df)

# Limit x-axis labels to the top 20
top_20_labels = clean_df['member_tenure_years'].value_counts().nlargest(20).index
plt.xticks(rotation=45, ha="right")

# Set x-axis labels for the top 20
plt.gca().set_xticklabels(top_20_labels)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25172\1085416758.py in <module>
#      13
#      14 # Set x-axis labels for the top 20
# ---> 15 plt.gca().set_xticklabels(top_20_labels)
#      16
#      17 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
#      73
#      74         def wrapper(self, *args, **kwargs):
# ---> 75             return get_method(self)(*args, **kwargs)
#      76
#      77         wrapper.__module__ = owner.__module__
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in _set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1796         if fontdict is not None:
#    1797             kwargs.update(fontdict)
# -> 1798         return self.set_ticklabels(labels, minor=minor, **kwargs)
#    1799
#    1800     def _set_tick_locations(self, ticks, *, minor=False):
# ...

# %%
sns.boxplot(x='accepted', y='age', data=clean_df)
# Out:
# <AxesSubplot:xlabel='accepted', ylabel='age'>

# %%
sns.boxplot(x='accepted', y='member_tenure_years', data=clean_df)
# Out:
# <AxesSubplot:xlabel='accepted', ylabel='member_tenure_years'>

# %% [markdown]
# ## STEP #2: Upgrade Membership Offer

# %%
clean_df['offer_name'].value_counts()
# Out:
# Offer ProtectMyID (PMID)    5782
# Add Associate               1714
# Upgrade Membership          1641
# Auto-Renew                  1344
# Name: offer_name, dtype: int64

# %%
upgrade=clean_df['offer_name']=="Upgrade Membership"
upgrade_df=clean_df[upgrade]

# %%
upgrade_df.shape
# Out:
# (1641, 30)

# %%
upgrade_df.dtypes
# Out:
# individual_key                      float64
# individual_key.1                    float64
# individual_key.2                    float64
# age                                 float64
# children                             object
# dwelling_type                        object
# education                            object
# estimated_income_code                object
# marital_status                       object
# gender                               object
# state                                object
# race_cleaned                         object
# city_cleaned                         object
# offer_name                           object
# accepted                            float64
# numofoffers                           int64
# acceptedoffers                      float64
# add_associate                        object
# auto-renew                           object
# offer_protectmyid                    object
# upgrade_membership                   object
# ...

# %%
upgrade_df['upgrade_membership'].value_counts()
# Out:
# NotAccepted    1251
# Accepted        390
# Name: upgrade_membership, dtype: int64

# %%
sns.boxplot(x=upgrade_df["age"])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.boxplot(x=upgrade_df["Average_Member_yrcost"])
# Out:
# <AxesSubplot:xlabel='Average_Member_yrcost'>

# %%
# filter to numerical columns
numericalColumns = upgrade_df.dtypes[upgrade_df.dtypes!=object]

num_columns=list(numericalColumns.index)

num_upgrade_df=upgrade_df[num_columns]

# %%
# heatmap for the first 20 numerical variables

correlation=round(num_upgrade_df[num_upgrade_df.columns[2:11]].corr(),2)

# change the size of the plot

plt.gcf().set_size_inches(10, 10)

#sns.heatmap(correlation)

sns.heatmap(correlation, cmap="YlGnBu", annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='upgrade_membership', y='credit_ranges', data=upgrade_df)
# Out:
# <AxesSubplot:xlabel='upgrade_membership', ylabel='credit_ranges'>

# %%
sns.boxplot(x='upgrade_membership', y='numofoffers', data=upgrade_df)
# Out:
# <AxesSubplot:xlabel='upgrade_membership', ylabel='numofoffers'>

# %%
upgrade_df['race_cleaned']=upgrade_df['race_cleaned'].str.split("-", n = 1, expand = True)[0]

upgrade_df['race_cleaned'].value_counts()

sns.catplot(x='upgrade_membership', y='age', hue='race_cleaned', kind='bar', data=upgrade_df)
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_22512\4285606401.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   upgrade_df['race_cleaned']=upgrade_df['race_cleaned'].str.split("-", n = 1, expand = True)[0]

# %%
sns.catplot(x='accepted', y='age', hue='offer_name', kind='point', data=clean_df)

# %%
sns.catplot(x='accepted', y='member_tenure_years', hue='offer_name', kind='point', data=clean_df)

# %%
sns.catplot(x='gender', y='accepted', hue='offer_name', kind='point', data=upgrade_df)

# %%
sns.catplot(x='state', y='accepted', hue='offer_name', kind='point', data=clean_df)

# %%
sns.catplot(x='upgrade_membership', y='age', hue='race_cleaned', kind='point', data=upgrade_df)

# %%
sns.catplot(x='upgrade_membership', y='age', hue='education', kind='bar', data=upgrade_df)

# %%
sns.catplot(x='upgrade_membership', y='age', hue='marital_status', kind='point', data=upgrade_df)

# %%
sns.catplot(x='upgrade_membership', y='age', hue='consumerview_profitability_score', kind='point', data=upgrade_df)

# %%
sns.catplot(x='upgrade_membership', y='age', hue='city_cleaned', kind='point', data=upgrade_df)

# %%
sns.catplot(x='upgrade_membership', y='numofoffers', hue='dwelling_type', kind='point', data=upgrade_df)

# %%
sns.barplot(x="numofoffers", y="accepted", data=upgrade_df)
# Out:
# <AxesSubplot:xlabel='numofoffers', ylabel='accepted'>

# %%
sns.barplot(x="member_type", y="accepted", data=upgrade_df)
# Out:
# <AxesSubplot:xlabel='member_type', ylabel='accepted'>

# %%
sns.catplot(x='upgrade_membership', y='member_tenure_years', hue='member_type', kind='point', data=upgrade_df)

# %%
sns.barplot(x="children", y="accepted", data=upgrade_df)
# Out:
# <AxesSubplot:xlabel='children', ylabel='accepted'>

# %%
sns.barplot(x="marital_status", y="accepted", data=upgrade_df)
# Out:
# <AxesSubplot:xlabel='marital_status', ylabel='accepted'>

# %%
sns.barplot(x="donor_flag", y="accepted", data=upgrade_df)
# Out:
# <AxesSubplot:xlabel='donor_flag', ylabel='accepted'>

# %%
sns.catplot(x='upgrade_membership', y='age', hue='children', kind='point', data=upgrade_df)

# %%
sns.catplot(x='upgrade_membership', y='age', hue='dwelling_type', kind='point', data=upgrade_df)

# %%
sns.catplot(x='upgrade_membership', y='Average_Member_yrcost', hue='member_type', kind='point', data=upgrade_df)
